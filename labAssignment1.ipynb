# %% [markdown]
# <a href="https://colab.research.google.com/github/HaroldOakland/ARK_BC/blob/main/labAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

# !git clone https://github.com/jcdevaney/musicComputing2025.git

file = 'musicComputing2025/audioFiles/avm.wav'
# Out:
# fatal: destination path 'musicComputing2025' already exists and is not an empty directory.

# %%
def plotAudio(file,samplingRate):

  sig, sr = librosa.load(file,mono=True, sr=samplingRate)
  time=np.arange(0,sig.shape[0])/sr

  librosa.load(file)

  xlabel = 'Time (seconds)'
  ylabel = 'Amplitude'


  plt.plot(time,sig)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)

# %%
file = 'musicComputing2025/audioFiles/avm.wav'
samplingRate = 44100
plotAudio(file, samplingRate)

# %%
file = 'musicComputing2025/audioFiles/avm.wav'
samplingRate = 441
plotAudio(file, samplingRate)
